# %%
import pandas as pd
import numpy as np

# Read in the data
df = pd.read_csv('finalFile-9may.csv')
df.columns=['id','no','Tweet']        

# Sample the data to speed up computation
# Comment out this line to match with lecture
#df = df.sample(frac=0.1, random_state=10)
print (f"Shape of dataframe is {df.shape}")
df.head()
X=df['Tweet']
#Z=df['Tweet']
#Z=df['Tweet'].to_string(index=False)

#print (df['Tweet'])

#print (X)

#print (Z)
# Out:
# Shape of dataframe is (727, 3)

# %%
import re  

import spacy

nlp = spacy.load('en_core_web_sm')

processed_tweets=[]

for tweet in range(0, len(X)):  
    processed_tweet = re.sub(r'\W', ' ', str(X[tweet]))

            
    # Remove all the special characters
    
    processed_tweet = re.sub(r'http\S+', ' ', processed_tweet)
    
    #processed_tweet = re.sub(r'https?:\/\/+', ' ', processed_tweet)
    
    #processed_tweet=re.sub(r'\w+:\/{2}[\d\w-]+(\.[\d\w-]+)*(?:(?:\/[^\s/]*))*', ' ',processed_tweet)
    
    processed_tweet=re.sub(r'www\S+', ' ', processed_tweet)
    
    processed_tweet=re.sub(r'co \S+', ' ', processed_tweet)
    # remove all single characters
    processed_tweet = re.sub(r'\s+[a-zA-Z]\s+', ' ', processed_tweet)
 
    # Remove single characters from the start
    processed_tweet = re.sub(r'\^[a-zA-Z]\s+', ' ', processed_tweet) 
 
    # Substituting multiple spaces with single space
    processed_tweet= re.sub(r'\s+', ' ', processed_tweet, flags=re.I)
 
    # Removing prefixed 'b'
    processed_tweet = re.sub(r'^b\s+', ' ', processed_tweet)
    
    processed_tweet = re.sub(r'\d','',processed_tweet)
    
    processed_tweet= re.sub(r'\s+', ' ', processed_tweet, flags=re.I)

 
    # Converting to Lowercase
    processed_tweet = processed_tweet.lower()
    
    processed_tweets.append(processed_tweet)
    
print (processed_tweets)
# Out:
# ['one of the boldest decisions of this election was making sadhvi prajya singh thakur candidate against digvijay singh hundred pranams to pm modi amp sri amit shah for this historic decision bhopal you have civilizational duty to fulfill hindus from around world are with you ', 'modi crosses century of rallies elections ', ' narendramodi even can bring the same crowd by paying per head and sending vans to pick up people from their houses ', 'if modi is pakistani agent you would be the first one to take his _____ in your mouth ', ' narendramodi justmodi modihiaayega delhiwithmodi ', ' bjpindia narendramodi ', 'retd vice admiral lambasts pm modi for ins viraat allegation claims rajiv gandhi was on official visit ', ' computerbaba digvijaya_ incindia narendramodi aajtak zeenews ', 'gst narendramodi sanjayazadsln ', 'modiji accuses rajiv gandhi of using the ins viraat for family vacation shocking if true compare that with selfless pm modiji he spent over cr of public money on touring in 
# ...

# %%
i=0
for entry in processed_tweets:
    i+=1
    with open ('cleaned_alpha.csv','a') as res:        
        writer=csv.writer(res)           
        #writer.writerow({i:"index" , ' '.join(entry):"tweet"})
        s="{},{}\n".format(i,entry)
        res.write(s)
        print (s)
# Out:
# 1,one of the boldest decisions of this election was making sadhvi prajya singh thakur candidate against digvijay singh hundred pranams to pm modi amp sri amit shah for this historic decision bhopal you have civilizational duty to fulfill hindus from around world are with you
#
# 2,modi crosses century of rallies elections
#
# 3, narendramodi even can bring the same crowd by paying per head and sending vans to pick up people from their houses
#
# 4,if modi is pakistani agent you would be the first one to take his _____ in your mouth
#
# 5, narendramodi justmodi modihiaayega delhiwithmodi
#
# 6, bjpindia narendramodi
#
# 7,retd vice admiral lambasts pm modi for ins viraat allegation claims rajiv gandhi was on official visit
#
# 8, computerbaba digvijaya_ incindia narendramodi aajtak zeenews
#
# 9,gst narendramodi sanjayazadsln
#
# ...

# %%
import csv
import pandas as pd
import spacy

nlp = spacy.load('en_core_web_sm')

df=pd.read_csv('cleaned_alpha.csv')
df.columns=['A','T']        
df.dropna(inplace=True)
#df = df.sample(frac=0.1, random_state=10)

print (df.head())     

tweets=df['T']#.to_string(index=False)

import spacy

nlp = spacy.load('en_core_web_sm')
i=0
count=0

list2=[]
for tweet in tweets:      
    doc = nlp(tweet)
    list1=[]
    for token in doc:
            if token.is_stop==False:
                print(token.text)
                list1.append(token.text)    
    list2.append(list1)
# Out:
#    A                                                  T
# 0  2         modi crosses century of rallies elections
# 1  3   narendramodi even can bring the same crowd by...
# 2  4  if modi is pakistani agent you would be the fi...
# 3  5   narendramodi justmodi modihiaayega delhiwithm...
# 4  6                             bjpindia narendramodi
# modi
# crosses
# century
# rallies
# elections
#
# narendramodi
# bring
# crowd
# paying
# head
# sending
# vans
# pick
# people
# houses
# modi
# pakistani
# agent
# _
# _
# _
# _
# _
# mouth
#
# narendramodi
# justmodi
# modihiaayega
# delhiwithmodi
#
# bjpindia
# narendramodi
# retd
# vice
# admiral
# lambasts
# pm
# modi
# ins
# viraat
# allegation
# claims
# rajiv
# gandhi
# official
# visit
#
# computerbaba
# digvijaya
# _
# incindia
# narendramodi
# aajtak
# zeenews
# gst
# narendramodi
# sanjayazadsln
# modiji
# accuses
# rajiv
# gandhi
# ins
# viraat
# family
# vacation
# shocking
# true
# compare
# selfless
# pm
# modiji
# spent
# cr
# ...

# %%
# Out:
#                                            :   # pmmodionabp # deshkishaanmodi https://t.co/ir5oalozt1
#
# @narendramodi massive crowd pm modis purulia . good bye didi !   # deshkishaanmodi    https://t.co/ba05ehpyos
#
# https://t.co/ozi7a65p3n @narendramodi govts strategic plan helped open 5 000 # janaushadhikendras & amp ; deliver 1 000 medicines half market price ..   strategic push resulted estimated savings rs . 1 000 crores public .. # namo
#
# modi overrated politician
#
# easy # goamining dependents drawing income particular industry shift industry . man owning mining truck operate trucks ? shop owner mining belt ? @narendramodi @nstomar @nitiaayog @goacm
#
# gdp       gas   diesel   petrol   ! # modikafakegdp https://t.co/z2igwzcliz
#
# @amitshah @bjp4up fortunate pm like modi . # deshkishaanmodi https://t.co/whwcf75oop
#
# buongiorno milano   # 9maggio @duomodimilano @3bmeteo @beautyfromitaly https://t.co/hmxr1fldh3
#
# @narendramodi   https://t.co/wn8itnxatc
#
# ...

# %%
i=0
for entry in list2:
    i+=1
    with open ('cleaned_alpha20.csv','a') as res:        
        writer=csv.writer(res)           
        #writer.writerow({i:"index" , ' '.join(entry):"tweet"})
        s="{},{}\n".format(i,' '.join(entry))
        res.write(s)
        print (s)
# Out:
# 1,modi crosses century rallies elections
#
# 2,  narendramodi bring crowd paying head sending vans pick people houses
#
# 3,modi pakistani agent _ _ _ _ _ mouth
#
# 4,  narendramodi justmodi modihiaayega delhiwithmodi
#
# 5,  bjpindia narendramodi
#
# 6,retd vice admiral lambasts pm modi ins viraat allegation claims rajiv gandhi official visit
#
# 7,  computerbaba digvijaya _ incindia narendramodi aajtak zeenews
#
# 8,gst narendramodi sanjayazadsln
#
# 9,modiji accuses rajiv gandhi ins viraat family vacation shocking true compare selfless pm modiji spent cr public money touring foreign policy took country ride
#
# 10,awaited interview pm narendramodi exclusively zeenews viewers pm modi started packing bags opponents daydreaming
#
# 11,saying neech bhasmasur maut ka saudagar naamard boti boti kar denge asking pakistan remove pm narendramodi navjot singh sidhu openly speaks rally chowkidar ko niptane aaya hoon narendra modi ko thokne aaya hoon cc bjpindia amitshah
#
# ...

# %%
import spacy

nlp = spacy.load('en_core_web_sm')
string='Apple is looking at buying U.K. startup for $1 billion'
doc = nlp(string)

for token in doc:
    if token.is_stop==True:
        string=string.replace("token.text",'')

    #print( token.is_stop)
    
#string=string.replace(str(spacy.lang.en.stop_words.STOP_WORDS),'')

print (string)
# Out:
# Apple is looking at buying U.K. startup for $1 billion

# %%
string='Apple is looking at buying U.K. startup for $1 billion'

string=string.replace("is",'')
#print (string.replace("is",''))
string=string.replace("at",'')
print (string)
# Out:
# Apple  looking  buying U.K. startup for $1 billion
